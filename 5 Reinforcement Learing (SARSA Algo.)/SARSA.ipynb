# %%
import sys
# !{sys.executable} -m pip show gymnasium
# Out:
# Name: gymnasium
# Version: 1.3.0
# Summary: A standard API for reinforcement learning and a diverse set of reference environments (formerly Gym).
# Home-page: https://farama.org
# Author:
# Author-email: Farama Foundation <contact@farama.org>
# License: MIT License
# Location: C:\Users\karan\AppData\Roaming\Python\Python313\site-packages
# Requires: cloudpickle, farama-notifications, numpy, typing-extensions
# Required-by:

# %%
import sys
# !{sys.executable} -m pip install "gymnasium[toy-text]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[toy-text] in C:\Users\karan\AppData\Roaming\Python\Python313\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in C:\ProgramData\anaconda3\Lib\site-packages (from gymnasium[toy-text]) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from gymnasium[toy-text]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from gymnasium[toy-text]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in C:\Users\karan\AppData\Roaming\Python\Python313\site-packages (from gymnasium[toy-text]) (0.0.6)
# Requirement already satisfied: pygame-ce>=2.1.3 in C:\Users\karan\AppData\Roaming\Python\Python313\site-packages (from gymnasium[toy-text]) (2.5.7)

# %%
# !pip install gymnasium
# Out:
# Access is denied.

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Access is denied.

# %%
import gymnasium as gym
import numpy as np
import random

# %%
# sample env
env = gym.make("CliffWalking-v1")

# %%
print(env.observation_space.n) # states
print(env.action_space.n) # actions

starting_state, _ = env.reset() # 36 = 3 * 12 + 0
print(starting_state) # 36
# Out:
# 48
# 4
# 36

# %% [markdown]
# ## SARSA

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500

# %%
# Q-table => store Q-values

Q = np.zeros((48, 4))

# %%
# Policy - epsilon-greedy : state -> action

def epsilon_greedy(state):
    if random.random() < epsilon:
        return env.action_space.sample() # random action => EXPLORE
    else:
        return np.argmax(Q[state])  # exploit

# %%
for episode in range(episodes):
    render = (episode % 50 == 0)

    if render:
        env = gym.make("CliffWalking-v1", render_mode="human")
        print(f"rendering env for episode={episode+1}/500")
    else:
        env = gym.make("CliffWalking-v1")

    done = False # when the episode has ended
    state, _ = env.reset()
    action = epsilon_greedy(state)

    total_reward = 0
    episode_len = 0

    while not done:
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        # SARSA update
        Q[state, action] += alpha * (reward + gamma*(Q[next_state, next_action] - Q[state, action]))

        state = next_state
        action = next_action

        total_reward += reward
        episode_len += 1

    print(f"episode={episode+1}/500: total reward = {total_reward} & ep length = {episode_len}")
    env.close()
# Out:
# rendering env for episode=1/500
# episode=1/500: total reward = -77 & ep length = 77
# episode=2/500: total reward = -1855 & ep length = 568
# episode=3/500: total reward = -208 & ep length = 109
# episode=4/500: total reward = -69 & ep length = 69
# episode=5/500: total reward = -87 & ep length = 87
# episode=6/500: total reward = -135 & ep length = 135
# episode=7/500: total reward = -33 & ep length = 33
# episode=8/500: total reward = -64 & ep length = 64
# episode=9/500: total reward = -71 & ep length = 71
# episode=10/500: total reward = -61 & ep length = 61
# episode=11/500: total reward = -160 & ep length = 61
# episode=12/500: total reward = -149 & ep length = 50
# episode=13/500: total reward = -69 & ep length = 69
# episode=14/500: total reward = -143 & ep length = 44
# episode=15/500: total reward = -52 & ep length = 52
# episode=16/500: total reward = -33 & ep length = 33
# episode=17/500: total reward = -67 & ep length = 67
# episode=18/500: total reward = -72 & ep length = 72
# episode=19/500: total reward = -21 & ep length = 21
# episode=20/500: total reward = -131 & ep length = 32
# episode=21/500: total reward = -45 & ep length = 45
# episode=22/500: total reward = -23 & ep length = 23
# episode=23/500: total reward = -50 & ep length = 50
# episode=24/500: total reward = -23 & ep length = 23
# episode=25/500: total reward = -31 & ep length = 31
# episode=26/500: total reward = -24 & ep length = 24
# episode=27/500: total reward = -37 & ep length = 37
# episode=28/500: total reward = -23 & ep length = 23
# episode=29/500: total reward = -21 & ep length = 21
# episode=30/500: total reward = -28 & ep length = 28
# episode=31/500: total reward = -44 & ep length = 44
# episode=32/500: total reward = -40 & ep length = 40
# episode=33/500: total reward = -21 & ep length = 21
# episode=34/500: total reward = -136 & ep length = 37
# episode=35/500: total reward = -19 & ep length = 19
# episode=36/500: total reward = -156 & ep length = 57
# episode=37/500: total reward = -31 & ep length = 31
# episode=38/500: total reward = -33 & ep length = 33
# episode=39/500: total reward = -39 & ep length = 39
# episode=40/500: total reward = -25 & ep length = 25
# episode=41/500: total reward = -25 & ep length = 25
# episode=42/500: total reward = -23 & ep length = 23
# episode=43/500: total reward = -25 & ep length = 25
# episode=44/500: total reward = -19 & ep length = 19
# episode=45/500: total reward = -19 & ep length = 19
# episode=46/500: total reward = -24 & ep length = 24
# episode=47/500: total reward = -272 & ep length = 74
# episode=48/500: total reward = -39 & ep length = 39
# episode=49/500: total reward = -27 & ep length = 27
# episode=50/500: total reward = -28 & ep length = 28
# rendering env for episode=51/500
# episode=51/500: total reward = -17 & ep length = 17
# episode=52/500: total reward = -32 & ep length = 32
# episode=53/500: total reward = -31 & ep length = 31
# episode=54/500: total reward = -27 & ep length = 27
# episode=55/500: total reward = -23 & ep length = 23
# episode=56/500: total reward = -15 & ep length = 15
# episode=57/500: total reward = -19 & ep length = 19
# episode=58/500: total reward = -37 & ep length = 37
# episode=59/500: total reward = -31 & ep length = 31
# episode=60/500: total reward = -31 & ep length = 31
# episode=61/500: total reward = -27 & ep length = 27
# episode=62/500: total reward = -17 & ep length = 17
# episode=63/500: total reward = -23 & ep length = 23
# episode=64/500: total reward = -23 & ep length = 23
# episode=65/500: total reward = -25 & ep length = 25
# episode=66/500: total reward = -39 & ep length = 39
# episode=67/500: total reward = -29 & ep length = 29
# episode=68/500: total reward = -32 & ep length = 32
# episode=69/500: total reward = -25 & ep length = 25
# episode=70/500: total reward = -25 & ep length = 25
# episode=71/500: total reward = -122 & ep length = 23
# episode=72/500: total reward = -20 & ep length = 20
# episode=73/500: total reward = -22 & ep length = 22
# episode=74/500: total reward = -23 & ep length = 23
# episode=75/500: total reward = -22 & ep length = 22
# episode=76/500: total reward = -30 & ep length = 30
# episode=77/500: total reward = -23 & ep length = 23
# episode=78/500: total reward = -27 & ep length = 27
# episode=79/500: total reward = -47 & ep length = 47
# episode=80/500: total reward = -38 & ep length = 38
# episode=81/500: total reward = -35 & ep length = 35
# episode=82/500: total reward = -20 & ep length = 20
# episode=83/500: total reward = -17 & ep length = 17
# episode=84/500: total reward = -28 & ep length = 28
# episode=85/500: total reward = -19 & ep length = 19
# episode=86/500: total reward = -26 & ep length = 26
# episode=87/500: total reward = -26 & ep length = 26
# episode=88/500: total reward = -23 & ep length = 23
# episode=89/500: total reward = -19 & ep length = 19
# episode=90/500: total reward = -17 & ep length = 17
# episode=91/500: total reward = -118 & ep length = 19
# episode=92/500: total reward = -22 & ep length = 22
# episode=93/500: total reward = -19 & ep length = 19
# episode=94/500: total reward = -31 & ep length = 31
# episode=95/500: total reward = -20 & ep length = 20
# episode=96/500: total reward = -17 & ep length = 17
# episode=97/500: total reward = -17 & ep length = 17
# episode=98/500: total reward = -20 & ep length = 20
# episode=99/500: total reward = -134 & ep length = 35
# episode=100/500: total reward = -17 & ep length = 17
# rendering env for episode=101/500
# episode=101/500: total reward = -17 & ep length = 17
# episode=102/500: total reward = -25 & ep length = 25
# episode=103/500: total reward = -19 & ep length = 19
# episode=104/500: total reward = -17 & ep length = 17
# episode=105/500: total reward = -19 & ep length = 19
# episode=106/500: total reward = -20 & ep length = 20
# episode=107/500: total reward = -18 & ep length = 18
# episode=108/500: total reward = -21 & ep length = 21
# episode=109/500: total reward = -18 & ep length = 18
# episode=110/500: total reward = -29 & ep length = 29
# episode=111/500: total reward = -17 & ep length = 17
# episode=112/500: total reward = -19 & ep length = 19
# episode=113/500: total reward = -22 & ep length = 22
# episode=114/500: total reward = -24 & ep length = 24
# episode=115/500: total reward = -19 & ep length = 19
# episode=116/500: total reward = -21 & ep length = 21
# episode=117/500: total reward = -17 & ep length = 17
# episode=118/500: total reward = -17 & ep length = 17
# episode=119/500: total reward = -19 & ep length = 19
# episode=120/500: total reward = -18 & ep length = 18
# episode=121/500: total reward = -20 & ep length = 20
# episode=122/500: total reward = -18 & ep length = 18
# episode=123/500: total reward = -19 & ep length = 19
# episode=124/500: total reward = -31 & ep length = 31
# episode=125/500: total reward = -24 & ep length = 24
# episode=126/500: total reward = -17 & ep length = 17
# episode=127/500: total reward = -23 & ep length = 23
# episode=128/500: total reward = -23 & ep length = 23
# episode=129/500: total reward = -21 & ep length = 21
# episode=130/500: total reward = -17 & ep length = 17
# episode=131/500: total reward = -21 & ep length = 21
# episode=132/500: total reward = -21 & ep length = 21
# episode=133/500: total reward = -39 & ep length = 39
# episode=134/500: total reward = -125 & ep length = 26
# episode=135/500: total reward = -18 & ep length = 18
# episode=136/500: total reward = -17 & ep length = 17
# episode=137/500: total reward = -21 & ep length = 21
# episode=138/500: total reward = -22 & ep length = 22
# episode=139/500: total reward = -18 & ep length = 18
# episode=140/500: total reward = -19 & ep length = 19
# episode=141/500: total reward = -19 & ep length = 19
# episode=142/500: total reward = -22 & ep length = 22
# episode=143/500: total reward = -27 & ep length = 27
# episode=144/500: total reward = -22 & ep length = 22
# episode=145/500: total reward = -21 & ep length = 21
# episode=146/500: total reward = -17 & ep length = 17
# episode=147/500: total reward = -21 & ep length = 21
# episode=148/500: total reward = -26 & ep length = 26
# episode=149/500: total reward = -40 & ep length = 40
# episode=150/500: total reward = -23 & ep length = 23
# rendering env for episode=151/500

# %%
# what did our agent learn?

env = gym.make("CliffWalking-v1", render_mode="human")
state, _ = env.reset()
done = False
total_reward = 0
episode_len = 0

while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    
    total_reward += reward
    episode_len += 1

print(f"total reward = {total_reward} & episode len = {episode_len}")
env.close()
